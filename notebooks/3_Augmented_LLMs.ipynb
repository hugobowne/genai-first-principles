# %% [markdown]
# # Session 6b: Multi-LLM Workflows
#
# ## Recap
# In Session 6a, you learned function calling—how to connect LLMs to external systems. While function calling connects LLMs to external systems, these workflows show how to coordinate multiple LLM calls to solve complex problems.
#
# ## What This Covers
# Single LLM calls often aren't enough. This notebook explores workflow patterns [inspired by Anthropic](https://www.anthropic.com/research/building-effective-agents):
#
# 1. **Prompt Chaining**: Sequential steps where each builds on the previous
# 2. **Parallelization**: Independent tasks running concurrently
# 3. **Routing**: Dynamic selection of specialized paths
# 4. **Orchestrator-Workers**: Coordinating multiple specialized LLMs for complex tasks
# 5. **Evaluator-Optimizer**: Iterative refinement with feedback loops
#
# **What you'll learn:** How to decompose complex problems into LLM workflows
#
# **By the end:** You'll understand when and how to use each pattern for real-world applications.

# %% [markdown]
# ## Setup
#
# First, set your API key and import the necessary libraries:

# %%
import os
os.environ['ANTHROPIC_API_KEY'] = 'XXX'

from concurrent.futures import ThreadPoolExecutor
from typing import List, Dict, Callable
from util import llm_call, extract_xml

# %% [markdown]
# ## 1. Prompt Chaining
#
# Prompt chaining breaks complex tasks into sequential steps where each LLM call builds on the previous output.

# %% [markdown]
# ![Prompt Chaining Workflow](img/prompt_chaining.png)
# *Image from Anthropic*

# %% [markdown]
# ### When to Use
# - When a task naturally breaks down into sequential steps
# - When each step's output feeds into the next step
# - When you need clear intermediate results
# - When order of operations matters
#
# ### Example: LinkedIn Profile Parser
# This example demonstrates prompt chaining by:
# 1. First extracting structured data from a profile
# 2. Then using that structured data to generate a personalized email
# 3. Each step builds on the output of the previous step

# %%
# Example 1: Chain workflow for structured data extraction and formatting

def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = llm_call(f"{prompt}\nInput: {result}")
        print(result)
    return result

def extract_structured_data(profile_text: str) -> str:
    """Extract all structured data from a LinkedIn profile in a single LLM call."""
    prompt = f"""
    Extract the following structured data from the LinkedIn profile text:
    - Full Name
    - Current Job Title and Company
    - Skills (as a comma-separated list)
    - Previous Job Titles (as a numbered list)

    Provide the output in this JSON format:
    {{
        "name": "Full Name",
        "current_position": "Position at Company",
        "skills": ["Skill1", "Skill2", ...],
        "previous_positions": ["Previous Position 1", "Previous Position 2", ...]
    }}

    LinkedIn Profile: {profile_text}
    """
    return llm_call(prompt)

def generate_outreach_email(data: str) -> str:
    """Generate a professional outreach email using the structured data."""
    prompt = f"""
    Using the following structured data, write a professional outreach email:
    {data}
    
    The email should:
    - Address the recipient by name.
    - Reference their current position and company.
    - Highlight relevant skills.
    - Politely request a meeting to discuss potential collaboration opportunities.
    """
    return llm_call(prompt)

# %%
# Example LinkedIn profile input
linkedin_profile_elliot = """
Elliot Alderson is a Cybersecurity Engineer at Allsafe Security. He specializes in penetration testing, network security, and ethical hacking.
Elliot has a deep understanding of UNIX systems, Python, and C, and is skilled in identifying vulnerabilities in corporate networks.
In his free time, Elliot is passionate about open-source projects and contributing to cybersecurity forums.
Previously, he worked as a freelance cybersecurity consultant, assisting clients in securing their online assets.
"""

# %% [markdown]
# Now let's execute the chain:

# %%
structured_data = extract_structured_data(linkedin_profile_elliot)
print("\nExtracted Structured Data:")
print(structured_data)
# Out:
# Extracted Structured Data:
# ```json
# {
#     "name": "Elliot Alderson",
#     "current_position": "Cybersecurity Engineer at Allsafe Security",
#     "skills": ["penetration testing", "network security", "ethical hacking", "UNIX systems", "Python", "C", "identifying vulnerabilities", "corporate networks", "open-source projects", "cybersecurity"],
#     "previous_positions": ["Freelance Cybersecurity Consultant"]
# }
# ```

# %% [markdown]
# Now generate the outreach email:

# %%
email = generate_outreach_email(structured_data)
print("\nGenerated Outreach Email:")
print(email)
# Out:
# Generated Outreach Email:
# Subject: Exploring Cybersecurity Collaboration Opportunities
#
# Dear Elliot,
#
# I hope this email finds you well. I'm reaching out to you given your impressive work as a Cybersecurity Engineer at Allsafe Security.
#
# I've been particularly interested in your expertise in penetration testing, network security, and ethical hacking, as well as your strong technical foundation in UNIX systems, Python, and C. Your experience in identifying vulnerabilities within corporate networks and your contributions to open-source projects demonstrate a comprehensive approach to cybersecurity that aligns well with the challenges we're currently addressing.
#
# Your background as a Freelance Cybersecurity Consultant also suggests you bring a diverse perspective to security solutions, which is invaluable in today's evolving threat landscape.
#
# I would greatly appreciate the opportunity to connect with you to discuss potential collaboration opportunities. I believe there may be meaningful ways we could work together or exchange insights that would be mutually beneficial.
#
# Would you be available for a brief meeting in the coming weeks? I'm happy to work around your schedule and can meet virtually or in person, whichever you prefer.
#
# Thank you for considering this request. I look forward to the possibility of connecting with you.
#
# Best regards,
#
# [Your Name]
# [Your Title]
# [Your Contact Information]

# %% [markdown]
# ## 2. Parallelization
#
# Parallelization runs independent LLM calls concurrently to speed up processing.

# %% [markdown]
# ![Parallelization Workflow](img/parallelization_workflow.png)
#
# *Image from Anthropic*

# %% [markdown]
# ### When to Use
# - When different aspects of a task can be processed independently
# - When you need to analyze multiple components simultaneously
# - When speed/performance is a priority
# - When you have multiple similar items to process (like batch processing)
#
#
# ### Example: LinkedIn Profile Field Extraction
# This example demonstrates parallelization by:
# 1. Simultaneously extracting different fields from a profile:
#    - Name extraction
#    - Position and company extraction
#    - Skills extraction
# 2. Using ThreadPoolExecutor to manage concurrent LLM calls
# 3. Combining the parallel extractions into a unified profile view

# %%
def parallel(prompt: str, inputs: List[str], n_workers: int = 3) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    with ThreadPoolExecutor(max_workers=n_workers) as executor:
        futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
        return [f.result() for f in futures]

# %%
# Define independent extraction tasks that will run in parallel
field_extraction_prompts = [
    """Extract the full name from the following LinkedIn profile text. Return only the name.
    LinkedIn Profile: {input}""",
    
    """Extract the current job title and company from the following LinkedIn profile text.
    Format as:
    Position: [Job Title]
    Company: [Company Name]
    LinkedIn Profile: {input}""",
    
    """Extract the skills mentioned in the following LinkedIn profile text. Return them as a comma-separated list.
    LinkedIn Profile: {input}""",
    
    """Extract the previous job titles from the following LinkedIn profile text. Return them as a numbered list, one per line.
    LinkedIn Profile: {input}"""
]

# %% [markdown]
# Execute the parallel extractions:

# %%
# Process all field extractions in parallel
extracted_fields = parallel(
    """Perform the following field extraction task:
    {input}""",
    [prompt.replace("{input}", linkedin_profile_elliot) for prompt in field_extraction_prompts]
)

# Assign extracted results to field names for clarity
field_names = ["Full Name", "Current Position and Company", "Skills", "Previous Positions"]
structured_data = {field: result for field, result in zip(field_names, extracted_fields)}

# Combine extracted fields into a JSON object
structured_data_json = {
    "name": structured_data["Full Name"],
    "current_position": structured_data["Current Position and Company"],
    "skills": structured_data["Skills"].split(", "),
    "previous_positions": structured_data["Previous Positions"].split("\n")
}

print("\nExtracted Structured Data (JSON):")
print(structured_data_json)
# Out:
# Extracted Structured Data (JSON):
# {'name': 'Elliot Alderson', 'current_position': 'Position: Cybersecurity Engineer\nCompany: Allsafe Security', 'skills': ['Based on the LinkedIn profile text', 'here are the extracted skills:\n\npenetration testing', 'network security', 'ethical hacking', 'UNIX systems', 'Python', 'C', 'vulnerability identification', 'cybersecurity consulting', 'open-source projects'], 'previous_positions': ['Based on the LinkedIn profile text, here are the previous job titles:', '', '1. Freelance cybersecurity consultant']}

# %% [markdown]
# Now generate an email using the parallel-extracted data:

# %%
# Create the email
email = generate_outreach_email(structured_data_json)

print("\nGenerated Outreach Email:")
print(email)
# Out:
# Generated Outreach Email:
# Subject: Exploring Cybersecurity Collaboration Opportunities
#
# Dear Elliot,
#
# I hope this message finds you well. I came across your profile and was impressed by your work as a Cybersecurity Engineer at Allsafe Security.
#
# Your extensive expertise in penetration testing, network security, and ethical hacking particularly caught my attention. Combined with your strong technical foundation in UNIX systems, Python, and C, as well as your experience in vulnerability identification and cybersecurity consulting, it's clear you bring significant value to the cybersecurity landscape. I also noticed your involvement in open-source projects, which speaks to your commitment to the broader security community.
#
# Given your background, including your previous experience as a freelance cybersecurity consultant, I believe there may be valuable opportunities for us to explore collaboration.
#
# Would you be open to a brief meeting in the coming weeks to discuss potential ways we might work together? I'm flexible with timing and happy to work around your schedule.
#
# Thank you for considering this request. I look forward to the possibility of connecting with you.
#
# Best regards,
#
# [Your Name]
# [Your Title]
# [Your Contact Information]

# %% [markdown]
# ## 3. Routing
#
# Routing classifies inputs and directs them to specialized handling paths based on their type.

# %% [markdown]
# ![Routing Workflow](img/routing_workflow.png)
# *Image from Anthropic*

# %% [markdown]
# ### When to Use
# - When input types require different specialized handling
# - When you need to direct tasks to specific LLM prompts
# - When input classification determines the processing path
# - When you have clearly defined categories of requests
#
# ### Example: LinkedIn Profile Classification
# This example demonstrates routing by:
# 1. Analyzing profiles to determine if they are:
#     - Individual profiles (for hiring outreach)
#     - Company profiles (for business development)
# 2. Using different email templates based on classification
# 3. Ensuring appropriate tone and content for each type

# %% [markdown]
# Let's implement the routing pattern:

# %%
# Define email routes for different profile types
email_routes = {
    "hiring": """You are a talent acquisition specialist. Write a professional email inviting the individual to discuss career opportunities. 
    Highlight their skills and current position. Maintain a warm and encouraging tone.

    Input: """,
    
    "collaboration": """You are a business development specialist. Write a professional email proposing a collaboration with the company. 
    Highlight mutual benefits and potential opportunities. Maintain a formal yet friendly tone.

    Input: """
}

# %% [markdown]
# Define the routing function that classifies and delegates:

# %%
def route_linkedin_profile(input: str, routes: Dict[str, str]) -> str:
    """Route LinkedIn profile to the appropriate email generation task."""
    print(f"\nAvailable routes: {list(routes.keys())}")
    selector_prompt = f"""
    Analyze the following LinkedIn profile and classify it as:
    - "hiring" if it represents an individual suitable for talent outreach.
    - "collaboration" if it represents a company profile suitable for business development outreach.

    Provide your reasoning in plain text, and then your decision in this format:

    <reasoning>
    Brief explanation of why this profile was classified into one of the routes. 
    Consider key signals like job titles, skills, organizational descriptions, and tone.
    </reasoning>

    <selection>
    The chosen route name
    </selection>

    Profile: {input}
    """
    # Call the LLM for classification
    route_response = llm_call(selector_prompt)

    # Extract reasoning and route selection
    reasoning = extract_xml(route_response, "reasoning")
    route_key = extract_xml(route_response, "selection").strip().lower()

    print("\nRouting Analysis:")
    print(reasoning)

    # Handle invalid classifications
    if route_key not in routes:
        print(f"Invalid classification '{route_key}', defaulting to 'hiring'")
        route_key = "hiring"

    # Route to the appropriate email template
    selected_prompt = routes[route_key]
    return llm_call(f"{selected_prompt}\nProfile: {input}")

# %% [markdown]
# Define example profile to test the router:

# %%
# Company profile
linkedin_profile_company = """
E Corp is a global leader in technology and financial services. With a portfolio spanning software development, cloud infrastructure,
and consumer banking, E Corp serves millions of customers worldwide. Our mission is to deliver innovative solutions that drive
efficiency and growth for businesses and individuals alike. Learn more at www.ecorp.com.
"""

# %% [markdown]
# Route and generate email for the individual (Elliot from earlier):

# %%
print("Processing Individual Profile:")
email_individual = route_linkedin_profile(linkedin_profile_elliot, email_routes)
print("\nGenerated Email:")
print(email_individual)
# Out:
# Processing Individual Profile:
#
# Available routes: ['hiring', 'collaboration']
#
# Routing Analysis:
#
# This profile represents an individual professional, not a company. Key indicators include:
#
# 1. **Individual identity**: "Elliot Alderson" is clearly a person's name, not a company name
# 2. **Job title and employer**: Listed as "Cybersecurity Engineer at Allsafe Security" - this shows an employee-employer relationship
# 3. **Personal skills and expertise**: The profile lists individual technical skills (penetration testing, Python, C, UNIX systems)
# 4. **Personal interests**: Mentions "his free time" and personal passions (open-source projects, forums)
# 5. **Career history**: References previous work as a "freelance cybersecurity consultant"
# 6. **Tone**: Written in third person about an individual's professional journey and capabilities
#
# This is clearly a personal professional profile of someone working in cybersecurity, making them a potential candidate for talent acquisition or recruitment purposes rather than a business development target.
#
#
# Generated Email:
# **Subject:** Exciting Career Opportunity for an Exceptional Cybersecurity Professional
#
# Dear Elliot,
#
# I hope this email finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I came across your profile and was genuinely impressed by your expertise and accomplishments in the cybersecurity field.
#
# Your current role as a Cybersecurity Engineer at Allsafe Security, combined with your specialized skills in penetration testing, network security, and ethical hacking, demonstrates a level of technical excellence that's rare to find. Your deep understanding of UNIX systems and proficiency in Python and C, along with your proven ability to identify and address vulnerabilities in corporate networks, truly sets you apart in the industry.
#
# I was also particularly drawn to your passion for open-source projects and your active contributions to cybersecurity forums—it speaks volumes about your commitment to the broader security community and continuous learning. Your background as a freelance cybersecurity consultant further showcases your versatility and client-focused approach.
#
# We're currently exploring opportunities that I believe would align beautifully with your skill set and career aspirations. I'd love to schedule a brief, informal conversation to discuss how your expertise might be a perfect fit for some exciting initiatives we have on the horizon.
#
# Would you be open to a 20-30 minute call in the coming week? I'm happy to work around your schedule.
#
# Looking forward to connecting with you.
#
# Warm regards,
#
# **[Your Name]**
# Talent Acquisition Specialist
# [Company Name]
# [Email Address]
# [Phone Number]
# [LinkedIn Profile]

# %% [markdown]
# Route and generate email for the company profile:

# %%
print("Processing Company Profile:")
email_company = route_linkedin_profile(linkedin_profile_company, email_routes)
print("\nGenerated Email:")
print(email_company)
# Out:
# Processing Company Profile:
#
# Available routes: ['hiring', 'collaboration']
#
# Routing Analysis:
#
# This profile represents a company rather than an individual. Key signals include:
#
# 1. **Organizational language**: Uses "E Corp is" and "Our mission" - typical corporate profile language rather than first-person individual narrative
# 2. **Company description**: Describes a business entity with multiple service lines (software development, cloud infrastructure, consumer banking)
# 3. **Scale indicators**: References "millions of customers worldwide" and "global leader" - indicating corporate scope
# 4. **Corporate website**: Includes a company website URL (www.ecorp.com)
# 5. **No individual identifiers**: Lacks personal job titles, individual skills, career history, or personal achievements
# 6. **Business focus**: Emphasizes services and solutions offered to customers, which is characteristic of a company profile
#
# This is clearly a company LinkedIn page suitable for business development, partnership discussions, or B2B collaboration opportunities rather than an individual who would be targeted for talent acquisition or hiring purposes.
#
#
# Generated Email:
# **Subject:** Strategic Collaboration Opportunity Between E Corp and [Your Company Name]
#
# Dear [Recipient Name/E Corp Partnership Team],
#
# I hope this message finds you well. My name is [Your Name], and I am reaching out on behalf of [Your Company Name] to explore a potential strategic collaboration with E Corp.
#
# Having followed E Corp's impressive trajectory in technology and financial services, I am particularly inspired by your commitment to delivering innovative solutions across software development, cloud infrastructure, and consumer banking. Your global reach and dedication to driving efficiency align remarkably well with our own organizational values and capabilities.
#
# **Why This Partnership Makes Sense**
#
# At [Your Company Name], we specialize in [briefly describe your core competencies]. We believe there are significant synergies between our organizations that could create substantial value for both parties:
#
# - **Expanded Market Reach**: Combining E Corp's established global presence with our [specific strength] could unlock new customer segments and geographic markets
# - **Enhanced Service Offerings**: Our expertise in [relevant area] could complement your existing portfolio, providing your millions of customers with even more comprehensive solutions
# - **Innovation Acceleration**: Collaborative development initiatives could fast-track product innovation and reduce time-to-market
# - **Operational Efficiencies**: Shared resources and knowledge exchange could optimize costs while improving service delivery
#
# **Proposed Next Steps**
#
# I would welcome the opportunity to discuss how we might work together in more detail. Perhaps we could schedule a brief introductory call at your convenience to explore:
#
# - Specific areas of mutual interest
# - Potential pilot projects or proof-of-concept initiatives
# - Framework for a mutually beneficial partnership
#
# Would you be available for a 30-minute conversation within the next two weeks? I am happy to work around your schedule.
#
# Thank you for considering this opportunity. I look forward to the possibility of building a successful partnership that drives growth and innovation for both E Corp and [Your Company Name].
#
# Warm regards,
#
# [Your Name]
# [Your Title]
# [Your Company Name]
# [Phone Number]
# [Email Address]
# [LinkedIn Profile]

# %% [markdown]
# ## 4. Orchestrator-Workers

# %% [markdown]
# ![alt text](img/orchestrator-worker.png "Title")
# *Image from Anthropic*

# %% [markdown]
# An orchestrator coordinates multiple specialized LLMs (workers) for complex tasks. The orchestrator classifies inputs, delegates to appropriate workers, and can synthesize results.
#
# ### When to Use
# - Complex tasks requiring multiple specialized steps
# - Different workers handle different aspects (classification, generation, validation)
# - Dynamic routing based on intermediate results
#
# ### Example: Industry-Specific Outreach
# This orchestrator:
# 1. Classifies a LinkedIn profile by industry (Tech vs Non-Tech)
# 2. Routes to specialized workers that generate industry-appropriate emails

# %% [markdown]
# Let's implement the orchestrator-worker pattern. First, define the email routes:

# %%
# Define the email generation routes for different industries
email_routes = {
    "tech": """You are a talent acquisition specialist in the tech industry. Write a professional email to the individual described below, inviting them to discuss career opportunities in the tech field.
    Highlight their skills and current position. Maintain a warm and encouraging tone.

    Input: {profile_text}""",

    "non_tech": """You are a talent acquisition specialist. Write a professional email to the individual described below, inviting them to discuss career opportunities.
    Highlight their skills and current position in a non-tech field. Maintain a warm and encouraging tone.

    Input: {profile_text}"""
}

# %% [markdown]
# Define the classification function:

# %%
def llm_classify(input: str) -> str:
    """Use LLM to classify the industry of the profile (Tech or Not Tech)."""
    classify_prompt = f"""
    Analyze the LinkedIn profile below and classify the industry as either Tech or Not Tech.
    
    LinkedIn Profile: {input}
    """
    classification = llm_call(classify_prompt)
    return classification.strip().lower()

# %% [markdown]
# Define the orchestrator and worker functions:

# %%
def orchestrator(input: str, routes: Dict[str, str]) -> str:
    """Classify the LinkedIn profile and assign tasks to workers based on the classification."""
    # Classify the profile industry
    industry = llm_classify(input)
    print(f"\nClassified industry as: {industry.capitalize()}")

    # Route to the appropriate worker
    if industry == "tech":
        task_responses = [tech_worker(input, routes)]
    else:
        task_responses = [non_tech_worker(input, routes)]
    
    return task_responses

def tech_worker(input: str, routes: Dict[str, str]) -> str:
    """Generate the email for Tech industry profiles."""
    selected_prompt = routes["tech"]
    return llm_call(selected_prompt.format(profile_text=input))

def non_tech_worker(input: str, routes: Dict[str, str]) -> str:
    """Generate the email for Non-Tech industry profiles."""
    selected_prompt = routes["non_tech"]
    return llm_call(selected_prompt.format(profile_text=input))

# %% [markdown]
# Define an example profile:

# %% [markdown]
# Process a profile through the orchestrator:

# %%
print("Processing Individual Profile (Elliot Alderson):")
email_responses_individual = orchestrator(linkedin_profile_elliot, email_routes)
print("\nGenerated Email:")
for response in email_responses_individual:
    print(response)
# Out:
# Processing Individual Profile (Elliot Alderson):
#
# Classified industry as: **classification: tech**
#
# **reasoning:**
#
# this linkedin profile clearly falls within the tech industry based on multiple indicators:
#
# 1. **job role**: cybersecurity engineer is a core technology position
# 2. **technical skills**: mentions specific technical competencies including:
#    - penetration testing
#    - network security
#    - ethical hacking
#    - unix systems
#    - programming languages (python, c)
#
# 3. **industry focus**: cybersecurity is a specialized sector within the technology industry
#
# 4. **work activities**: identifying vulnerabilities in corporate networks and securing online assets are technology-focused responsibilities
#
# 5. **professional interests**: contributing to open-source projects and cybersecurity forums are activities firmly rooted in the tech community
#
# this profile represents a quintessential technology professional working in the cybersecurity domain.
#
# Generated Email:
# **Subject: Exciting Career Opportunity for an Exceptional Cybersecurity Professional**
#
# Dear Elliot,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I came across your profile and was genuinely impressed by your expertise and accomplishments in the cybersecurity field.
#
# Your current role as a Cybersecurity Engineer at Allsafe Security, combined with your specialized skills in penetration testing, network security, and ethical hacking, demonstrates a level of technical excellence that is truly remarkable. Your deep understanding of UNIX systems and proficiency in Python and C, along with your proven ability to identify and address vulnerabilities in corporate networks, sets you apart as a leader in this critical field.
#
# What particularly caught my attention is your passion for the cybersecurity community—your contributions to open-source projects and active participation in cybersecurity forums reflect not only your technical prowess but also your commitment to advancing the field and helping others.
#
# Given your impressive background, including your experience as a freelance cybersecurity consultant, I believe you would be an excellent fit for some exciting opportunities we're currently exploring. I'd love to schedule a brief conversation to discuss how your skills and career aspirations might align with what we have to offer.
#
# Would you be open to a 20-30 minute call in the coming week? I'm happy to work around your schedule.
#
# Thank you for considering this opportunity, Elliot. I look forward to the possibility of connecting with you.
#
# Warm regards,
#
# [Your Name]
# [Your Title]
# [Company Name]
# [Email Address]
# [Phone Number]

# %% [markdown]
# Let's run the orchestrator on several different profiles to see how it classifies and routes them:

# %%
# Example LinkedIn profiles across Industries (for orchestrator-workers workflow)

# Tony Stark (Engineering - Entertainment/Tech Industry)
linkedin_profile_tony_stark = """
Tony Stark is the CEO of Stark Industries and a renowned inventor and engineer. He specializes in advanced robotics, artificial intelligence, and defense technologies.
Tony is best known for creating the Iron Man suit and leading innovations in the field of clean energy. He has a passion for pushing the boundaries of science and technology to protect humanity.
Previously, Tony Stark served as an inventor and entrepreneur, having founded Stark Industries and revolutionized the defense industry.
"""

# Sheryl Sandberg (Business - Tech Industry)
linkedin_profile_sheryl_sandberg = """
Sheryl Sandberg is the Chief Operating Officer at Facebook (Meta), specializing in business operations, scaling organizations, and team management.
She has a strong background in strategic planning, marketing, and organizational leadership. Previously, Sheryl served as Vice President of Global Online Sales and Operations at Google.
She is also the author of *Lean In*, a book focused on empowering women in leadership positions.
"""

# Elon Musk (Entrepreneur - Tech/Space Industry)
linkedin_profile_elon_musk = """
Elon Musk is the CEO of SpaceX and Tesla, Inc. He is an entrepreneur and innovator with a focus on space exploration, electric vehicles, and renewable energy.
Musk's work has revolutionized the automotive industry with Tesla’s electric vehicles and space exploration with SpaceX’s reusable rockets. He is also the founder of The Boring Company and Neuralink.
Musk is dedicated to advancing sustainable energy solutions and enabling human life on Mars.
"""

# Walter White (Chemistry - Entertainment/Film Industry)
linkedin_profile_walter_white = """
Walter White is a former high school chemistry teacher turned chemical engineer, best known for his work in the methamphetamine production industry.
Initially, Walter worked as a chemistry professor at a university before turning to a life of crime to secure his family's future.
Over time, he became an expert in chemical processes and synthesis, and his work has had profound impacts on the illegal drug trade. He is currently retired and focusing on his personal legacy.
"""

# Hermione Granger (Education - Literary/Film Industry)
linkedin_profile_hermione_granger = """
Hermione Granger is a research specialist at the Department of Magical Research and Development, focusing on magical education and the preservation of magical history.
She specializes in spellcraft, magical law, and potion-making. Hermione has worked closely with the Ministry of Magic to develop educational programs for young witches and wizards.
In her earlier years, she attended Hogwarts School of Witchcraft and Wizardry, where she excelled in every subject. She's passionate about equal rights for magical creatures and is an advocate for social justice.
"""

# %%
# Process the LinkedIn profiles and generate emails
profiles = [
    linkedin_profile_elliot,
    linkedin_profile_tony_stark, linkedin_profile_sheryl_sandberg,
    linkedin_profile_elon_musk, linkedin_profile_walter_white,
    linkedin_profile_hermione_granger
]

# Process each profile
for profile in profiles:
    print("\nProcessing LinkedIn Profile:")
    email_responses = orchestrator(profile, email_routes)
    print("\nGenerated Emails:")
    for response in email_responses:
        print(response)
# Out:
# Processing LinkedIn Profile:
#
# Classified industry as: **classification: tech**
#
# **reasoning:**
#
# this linkedin profile clearly falls within the tech industry based on multiple indicators:
#
# 1. **job title & role**: cybersecurity engineer is a core technology position
# 2. **technical skills**: mentions specific technical competencies including:
#    - penetration testing
#    - network security
#    - ethical hacking
#    - unix systems
#    - programming languages (python, c)
#
# 3. **industry focus**: cybersecurity is a specialized sector within the technology industry
#
# 4. **work activities**: identifying vulnerabilities in corporate networks and securing online assets are technology-focused responsibilities
#
# 5. **professional interests**: contributing to open-source projects and cybersecurity forums are hallmarks of tech industry engagement
#
# this profile represents a quintessential technology professional working in the cybersecurity domain.
#
# Generated Emails:
# **Subject: Exciting Career Opportunity for an Exceptional Cybersecurity Professional**
#
# Dear Elliot,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I came across your profile and was genuinely impressed by your expertise and accomplishments in the cybersecurity field.
#
# Your current role as a Cybersecurity Engineer at Allsafe Security, combined with your specialized skills in penetration testing, network security, and ethical hacking, demonstrates a level of technical excellence that is truly remarkable. Your deep understanding of UNIX systems and proficiency in Python and C, along with your proven ability to identify and address vulnerabilities in corporate networks, sets you apart as a leader in this critical field.
#
# What particularly caught my attention is your passion for the cybersecurity community—your contributions to open-source projects and active participation in cybersecurity forums speak volumes about your commitment to advancing the industry and sharing knowledge with others. Your background as a freelance cybersecurity consultant further showcases your versatility and dedication to protecting digital assets.
#
# I believe your unique skill set and experience would be an excellent fit for some exciting opportunities we're currently exploring. I would love to schedule a brief conversation to discuss how your career goals align with what we have to offer, and to learn more about what you're looking for in your next professional chapter.
#
# Would you be available for a 20-30 minute call in the coming week? I'm happy to work around your schedule.
#
# Thank you for considering this opportunity, Elliot. I look forward to the possibility of connecting with you.
#
# Warm regards,
#
# [Your Name]
# Talent Acquisition Specialist
# [Company Name]
# [Email Address]
# [Phone Number]
#
# Processing LinkedIn Profile:
#
# Classified industry as: **classification: tech**
#
# **analysis:**
#
# tony stark's profile clearly falls within the tech industry based on several key indicators:
#
# 1. **core specializations**: advanced robotics, artificial intelligence, and defense technologies are all technology-driven fields
#
# 2. **innovation focus**: creating the iron man suit and leading clean energy innovations demonstrates cutting-edge technological development
#
# 3. **professional identity**: described as an inventor and engineer with expertise in science and technology
#
# 4. **company nature**: while stark industries has defense industry ties, the profile emphasizes the technological innovation aspect rather than traditional defense contracting
#
# 5. **career focus**: the emphasis on "pushing the boundaries of science and technology" clearly positions this profile in the tech sector
#
# the profile represents a technology-focused leader working at the intersection of ai, robotics, clean energy, and advanced engineering - all hallmarks of the tech industry.
#
# Generated Emails:
# **Subject:** Exciting Opportunity to Explore New Horizons – We'd Love to Connect, Tony
#
# ---
#
# Dear Tony,
#
# I hope this message finds you well and thriving in your groundbreaking work at Stark Industries.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I've been following your remarkable career with great admiration—from revolutionizing the defense industry to your pioneering innovations in advanced robotics, artificial intelligence, and clean energy solutions. Your work, particularly the development of the Iron Man suit and your commitment to leveraging technology for humanity's protection, truly sets you apart as a visionary leader.
#
# While I recognize that you're currently excelling as CEO of Stark Industries, I wanted to reach out because we believe exceptional talent like yours deserves to know about opportunities that align with pushing boundaries and making meaningful impact. At [Company Name], we're working on [brief description of relevant projects/mission], and we see tremendous synergy with your expertise in AI, robotics, and sustainable technology.
#
# I'd love the opportunity to have a brief, no-pressure conversation with you to explore how your unique skills and passion for innovation might align with some exciting initiatives we have on the horizon. Even if the timing isn't right, I believe the conversation could be mutually valuable.
#
# Would you be open to a 20-minute call in the coming weeks? I'm happy to work around your schedule.
#
# Thank you for considering this, Tony. Looking forward to the possibility of connecting.
#
# Warm regards,
#
# **[Your Name]**
# Talent Acquisition Specialist
# [Company Name]
# [Email] | [Phone]
# [LinkedIn Profile]
#
# Processing LinkedIn Profile:
#
# Classified industry as: **classification: tech**
#
# **analysis:**
#
# this linkedin profile clearly falls within the tech industry based on the following key indicators:
#
# 1. **current role**: chief operating officer at facebook/meta - a major technology and social media company
#
# 2. **previous experience**: vice president of global online sales and operations at google - another leading technology company
#
# 3. **industry context**: both facebook/meta and google are core technology companies operating in social media, digital advertising, and internet services
#
# 4. **career pattern**: the progression from google to facebook demonstrates a career trajectory firmly rooted in the technology sector
#
# while sheryl sandberg's expertise includes general business operations and leadership (which could apply to any industry), her professional experience has been exclusively with major technology companies, making this definitively a **tech industry profile**.
#
# Generated Emails:
# **Subject:** Exploring Exciting Leadership Opportunities – Your Expertise Caught Our Attention
#
# Dear Sheryl,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I've been following your remarkable career trajectory with great admiration, and I'm reaching out because I believe your exceptional expertise aligns beautifully with some exciting opportunities we're currently exploring.
#
# Your proven track record in business operations and organizational scaling—particularly your transformative work at Meta and Google—demonstrates a rare combination of strategic vision and operational excellence. Your ability to build and lead high-performing teams while driving sustainable growth is truly impressive. Beyond your corporate achievements, your commitment to empowering women in leadership through *Lean In* speaks volumes about your values and dedication to creating meaningful impact.
#
# We're currently seeking visionary leaders who can bring strategic planning expertise, marketing acumen, and organizational leadership to [brief description of role/company focus]. Given your background in scaling global operations and fostering inclusive workplace cultures, I believe there could be a compelling mutual fit worth exploring.
#
# I'd love the opportunity to connect for a brief, no-obligation conversation to share more about these opportunities and learn about what might interest you in your next chapter. Would you be open to a 20-30 minute call in the coming weeks?
#
# Thank you for considering this outreach. I look forward to the possibility of connecting with you.
#
# Warm regards,
#
# [Your Name]
# [Your Title]
# [Company Name]
# [Email Address]
# [Phone Number]
#
# Processing LinkedIn Profile:
#
# Classified industry as: **classification: tech**
#
# **reasoning:**
#
# this profile clearly falls within the tech industry based on multiple indicators:
#
# 1. **core companies**: spacex (aerospace technology/space exploration) and tesla (electric vehicles with advanced software/ai) are both technology-driven companies
#
# 2. **technology focus areas**:
#    - space exploration and reusable rocket technology
#    - electric vehicles with autonomous driving capabilities
#    - renewable energy solutions
#    - neuralink (brain-computer interface technology)
#    - the boring company (infrastructure technology)
#
# 3. **innovation-driven**: the profile emphasizes innovation, technological advancement, and cutting-edge solutions across multiple sectors
#
# 4. **industry impact**: the work described involves revolutionizing traditional industries through technology implementation
#
# all activities mentioned are rooted in advanced technology, engineering, and innovation, making this definitively a **tech industry** profile.
#
# Generated Emails:
# **Subject: Exploring Exciting Career Opportunities – Your Leadership in Innovation**
#
# Dear Mr. Musk,
#
# I hope this message finds you well.
#
# I'm reaching out because your remarkable work as CEO of SpaceX and Tesla, Inc. has truly captured our attention. Your entrepreneurial vision and innovative approach to solving some of humanity's most pressing challenges—from sustainable energy to space exploration—demonstrate the kind of forward-thinking leadership that inspires industries worldwide.
#
# Your success in revolutionizing the automotive sector through Tesla's electric vehicles and transforming space exploration with SpaceX's groundbreaking reusable rocket technology showcases not only your technical acumen but also your exceptional ability to lead teams, drive innovation, and execute ambitious visions. Your ventures with The Boring Company and Neuralink further exemplify your versatility and commitment to pushing boundaries.
#
# While I recognize you're deeply engaged in your current endeavors, I wanted to reach out to explore whether you might be interested in discussing potential career opportunities that could benefit from your unique expertise in strategic leadership, innovation management, and sustainable technology development.
#
# We believe that leaders with your track record of turning ambitious ideas into reality could bring tremendous value to organizations seeking transformative change.
#
# Would you be open to a brief, no-obligation conversation to explore how your skills and vision might align with exciting opportunities we're currently working on?
#
# I'd be happy to work around your schedule for a call at your convenience.
#
# Thank you for considering this outreach, and continued success with your groundbreaking work.
#
# Warm regards,
#
# [Your Name]
# Talent Acquisition Specialist
# [Company Name]
# [Contact Information]
#
# Processing LinkedIn Profile:
#
# Classified industry as: # industry classification: **not tech**
#
# ## analysis:
#
# while walter white has a background in chemistry and chemical engineering, his primary industry involvement is in **illegal drug manufacturing/methamphetamine production**, which falls under:
#
# - **illegal/criminal enterprise**
# - **pharmaceutical manufacturing (illegal sector)**
# - **chemical production (illicit)**
#
# ## reasoning:
#
# **why not tech:**
# - the tech industry typically encompasses software development, it services, hardware manufacturing, telecommunications, biotechnology (legitimate), and digital services
# - chemical synthesis for illegal drug production does not fall under the technology sector
# - his work is in clandestine chemistry/narcotics manufacturing, not legitimate pharmaceutical or biotech industries
#
# **industry classification:**
# this profile would be classified under **illegal activities/criminal enterprise** rather than any legitimate industry category. if forced to choose a broader legal industry category, it would be closest to **chemicals/pharmaceuticals**, but specifically in an illicit context.
#
# **conclusion:** **not tech**
#
# Generated Emails:
# **Subject: Exploring New Opportunities in Chemical Engineering and Process Development**
#
# Dear Mr. White,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a talent acquisition specialist with [Company Name]. I came across your impressive background in chemistry and chemical engineering, and I wanted to reach out personally to explore whether you might be interested in discussing some exciting career opportunities that align with your exceptional skill set.
#
# Your journey from chemistry education to advanced chemical process development demonstrates a rare combination of theoretical knowledge and practical application expertise. Your deep understanding of chemical synthesis, process optimization, and quality control represents exactly the kind of specialized talent that leading organizations in the pharmaceutical, materials science, and chemical manufacturing sectors are actively seeking.
#
# Given your background as an educator and your advanced technical capabilities, I believe there are several legitimate industry positions where your expertise could make a significant positive impact—whether in research and development, process engineering, quality assurance, or even returning to education in a consulting or advisory capacity.
#
# I understand you're currently retired and focused on personal matters, but I wanted to extend this invitation in case you're open to exploring opportunities that would allow you to apply your considerable talents in a meaningful and rewarding way.
#
# Would you be available for a brief, confidential conversation to discuss what might interest you at this stage of your career? I'm happy to work around your schedule.
#
# Thank you for considering this outreach, and I look forward to the possibility of speaking with you.
#
# Warm regards,
#
# [Your Name]
# [Title]
# [Company Name]
# [Contact Information]
#
# Processing LinkedIn Profile:
#
# Classified industry as: **classification: not tech**
#
# **analysis:**
#
# this profile describes someone working in a fictional magical/fantasy context, but translating to real-world equivalents, this would be classified as **not tech** for the following reasons:
#
# 1. **industry focus**: the role is in research, education, and policy development within a specialized academic/governmental field - not technology development or software/hardware engineering.
#
# 2. **core competencies**: the skills mentioned (spellcraft, magical law, potion-making, educational program development) align more with:
#    - education/academia
#    - government/public policy
#    - research (non-technical)
#    - social advocacy
#
# 3. **work context**: employment at a government ministry's research and development department focused on education and historical preservation is more aligned with public sector education/research rather than the technology industry.
#
# 4. **career path**: academic excellence and transition into educational program development and social advocacy work is typical of education, policy, or non-profit sectors rather than tech.
#
# while "research and development" appears in the title, the context clearly indicates this is educational and historical research rather than technological r&d.
#
# Generated Emails:
# **Subject:** Exciting Career Opportunity for an Exceptional Research Specialist
#
# Dear Ms. Granger,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a talent acquisition specialist at [Company Name]. I've been following your impressive work at the Department of Magical Research and Development, and I'm reaching out because I believe your unique expertise and passion could be an excellent fit for some exciting opportunities we're currently exploring.
#
# Your background in magical education and historical preservation, combined with your specialized knowledge in spellcraft, magical law, and potion-making, demonstrates a rare combination of technical expertise and strategic thinking. The educational programs you've developed in collaboration with the Ministry of Magic showcase not only your subject matter mastery but also your ability to translate complex concepts into accessible learning frameworks—a skill that's invaluable in any field.
#
# What particularly stands out is your commitment to social justice and advocacy for equal rights. Your dedication to creating positive change, paired with your distinguished academic record from Hogwarts, reflects the kind of principled leadership and intellectual rigor we deeply value.
#
# I would love the opportunity to discuss how your talents might align with some career paths that could offer new challenges and growth opportunities. Would you be open to a brief, no-obligation conversation in the coming weeks? I'm confident that your skills are highly transferable and could open doors you might not have previously considered.
#
# Please let me know if you'd be interested in connecting. I'm happy to work around your schedule.
#
# Warm regards,
#
# [Your Name]
# [Your Title]
# [Company Name]
# [Contact Information]

# %% [markdown]
# ## 5. Evaluator-Optimizer
#
# An evaluator-optimizer workflow uses iterative refinement. A generator creates output, an evaluator assesses it, and an optimizer improves it based on feedback.

# %% [markdown]
# ![Evaluator-Optimizer Workflow](img/evaluator-optimizer.png)
# *Image from Anthropic*

# %% [markdown]
# ### When to Use
# - Iterative improvement needed to meet quality criteria
# - Clear evaluation standards available
# - Task benefits from feedback loops
#
# ### Example: Refining Outreach Emails
# This workflow:
# 1. Generates an initial email from a LinkedIn profile
# 2. Evaluates it for professionalism, tone, and clarity
# 3. Optimizes based on feedback until quality criteria are met

# %% [markdown]
# Let's implement the evaluator-optimizer pattern. First, define the email route:

# %%
# Define the email generation route
email_routes = {
    "hiring": """You are a talent acquisition specialist. Write a professional email to the individual described below, inviting them to discuss career opportunities. 
    Highlight their skills and current position. Maintain a warm and encouraging tone.

    Input: {profile_text}"""
}

# %% [markdown]
# Define the email generator function:

# %%
def llm_generate_email(input: str, routes: Dict[str, str]) -> str:
    """Generate an email based on the LinkedIn profile."""
    selected_prompt = routes["hiring"]
    return llm_call(selected_prompt.format(profile_text=input))

# %% [markdown]
# Define the evaluator function:

# %%
def llm_evaluate_email(email: str) -> str:
    """Evaluate the generated email for professionalism, tone, and clarity."""
    evaluation_prompt = f"""
    Please review the following email and provide feedback.
    The goal is to ensure it is professional, clear, and maintains a warm tone. If it needs improvements, provide suggestions.

    Email: {email}
    """
    return llm_call(evaluation_prompt)

# %% [markdown]
# Define the optimizer function:

# %%
def llm_optimize_email(email: str, feedback: str) -> str:
    """Refine the generated email based on evaluator feedback."""
    optimization_prompt = f"""
    Based on the following feedback, improve the email. Ensure it remains professional and clear while implementing the suggested changes.

    Feedback: {feedback}
    Email: {email}
    """
    return llm_call(optimization_prompt)

# %% [markdown]
# Define the orchestrator that coordinates the generator, evaluator, and optimizer:

# %%
def eval_optimizer_workflow(input: str, routes: Dict[str, str]) -> str:
    """Generate, evaluate, and optimize the email."""
    # Step 1: Generate the initial email
    email = llm_generate_email(input, routes)
    print("\nInitial Generated Email:")
    print(email)

    # Step 2: Evaluate the email
    feedback = llm_evaluate_email(email)
    print("\nEvaluator Feedback:")
    print(feedback)

    # Step 3: Optimize the email based on feedback
    optimized_email = llm_optimize_email(email, feedback)
    print("\nOptimized Email:")
    print(optimized_email)

    return optimized_email

# %% [markdown]
# Process Elliot's profile:

# %%
print("Processing LinkedIn Profile (Elliot Alderson):")
final_email = eval_optimizer_workflow(linkedin_profile_elliot, email_routes)

print("\nFinal Optimized Email:")
print(final_email)
# Out:
# Processing LinkedIn Profile (Elliot Alderson):
#
# Initial Generated Email:
# **Subject: Exciting Career Opportunity for an Exceptional Cybersecurity Professional**
#
# Dear Elliot,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I came across your profile and was genuinely impressed by your expertise and accomplishments in the cybersecurity field.
#
# Your current role as a Cybersecurity Engineer at Allsafe Security, combined with your specialized skills in penetration testing, network security, and ethical hacking, demonstrates a level of technical excellence that's rare to find. Your deep understanding of UNIX systems, Python, and C, along with your proven ability to identify and address vulnerabilities in corporate networks, speaks volumes about your capabilities and dedication to the field.
#
# I was particularly intrigued by your passion for open-source projects and your active contributions to cybersecurity forums—it's clear that your commitment to cybersecurity extends well beyond your professional responsibilities. Your background as a freelance cybersecurity consultant also highlights your versatility and client-focused approach to securing digital assets.
#
# We are currently exploring opportunities for talented professionals like yourself, and I believe your skill set and experience would be an excellent fit for some exciting positions we're looking to fill. I'd love to schedule a brief conversation to discuss how your career goals align with the opportunities we have available.
#
# Would you be open to a confidential call in the coming week? I'm flexible with timing and happy to work around your schedule.
#
# Thank you for considering this opportunity, Elliot. I look forward to the possibility of connecting with you.
#
# Warm regards,
#
# [Your Name]
# Talent Acquisition Specialist
# [Company Name]
# [Email Address]
# [Phone Number]
#
# Evaluator Feedback:
# ## Email Review & Feedback
#
# **Overall Assessment:** This is a well-crafted recruiting email that successfully balances professionalism with warmth. However, it could be more effective with some strategic adjustments.
#
# ---
#
# ## Strengths ✓
# - Personalized and specific to the candidate's background
# - Professional yet approachable tone
# - Clear call-to-action
# - Well-structured and easy to read
# - Demonstrates genuine research into the candidate's profile
#
# ---
#
# ## Areas for Improvement
#
# ### 1. **Length** ⚠️
# The email is quite long for an initial outreach. Busy professionals may not read through all the details.
#
# **Suggestion:** Condense the second and third paragraphs into one focused paragraph highlighting 2-3 key accomplishments.
#
# ### 2. **Vague Opportunity Description** ⚠️
# "Exciting positions we're looking to fill" is too generic and may seem like a mass email.
#
# **Suggestion:** Provide at least a hint about the role level, team, or type of work (e.g., "senior-level positions focused on threat detection" or "leadership opportunities in our security operations team").
#
# ### 3. **Missing Value Proposition**
# You mention what impresses you about Elliot, but not what makes your company/opportunity compelling.
#
# **Suggestion:** Add 1-2 sentences about what makes your company unique (culture, projects, growth opportunities, tech stack, etc.).
#
# ---
#
# ## Revised Version
#
# **Subject: Exciting Career Opportunity for an Exceptional Cybersecurity Professional**
#
# Dear Elliot,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I came across your profile and was genuinely impressed by your expertise in cybersecurity, particularly your work at Allsafe Security and your specialized skills in penetration testing and ethical hacking. Your contributions to open-source projects and active engagement in cybersecurity forums also caught my attention—it's clear your passion extends well beyond your day-to-day responsibilities.
#
# We're currently seeking exceptional cybersecurity talent for **[senior-level positions/leadership roles/specific team]** at [Company Name], where we're **[brief compelling detail: e.g., "building next-generation threat detection systems" or "protecting critical infrastructure for Fortune 500 clients"]**. Given your background and technical expertise, I believe there could be a strong mutual fit worth exploring.
#
# Would you be open to a brief, confidential conversation in the coming week? I'm flexible with timing and happy to work around your schedule.
#
# Thank you for considering this opportunity, Elliot. I look forward to the possibility of connecting with you.
#
# Warm regards,
#
# [Your Name]
# Talent Acquisition Specialist
# [Company Name]
# [Email Address]
# [Phone Number]
#
# ---
#
# ## Key Changes Made:
# ✅ Reduced length by ~40% while maintaining personalization
# ✅ Added specificity about the opportunity
# ✅ Included a value proposition for the company
# ✅ Maintained warm, professional tone
# ✅ Kept the clear call-to-action
#
# This revision respects the candidate's time while still demonstrating genuine interest and providing enough information to spark curiosity.
#
# Optimized Email:
# **Subject: Exciting Career Opportunity for an Exceptional Cybersecurity Professional**
#
# Dear Elliot,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I came across your profile and was genuinely impressed by your expertise in cybersecurity, particularly your work at Allsafe Security and your specialized skills in penetration testing and ethical hacking. Your contributions to open-source projects and active engagement in cybersecurity forums also caught my attention—it's clear your passion extends well beyond your day-to-day responsibilities.
#
# We're currently seeking exceptional cybersecurity talent for **senior-level positions focused on advanced threat detection and network security** at [Company Name], where we're **building cutting-edge security solutions for enterprise clients and fostering a culture of innovation and continuous learning**. Given your technical expertise and proven track record in identifying and addressing complex vulnerabilities, I believe there could be a strong mutual fit worth exploring.
#
# Would you be open to a brief, confidential conversation in the coming week? I'm flexible with timing and happy to work around your schedule.
#
# Thank you for considering this opportunity, Elliot. I look forward to the possibility of connecting with you.
#
# Warm regards,
#
# [Your Name]
# Talent Acquisition Specialist
# [Company Name]
# [Email Address]
# [Phone Number]
#
# Final Optimized Email:
# **Subject: Exciting Career Opportunity for an Exceptional Cybersecurity Professional**
#
# Dear Elliot,
#
# I hope this message finds you well.
#
# My name is [Your Name], and I'm a Talent Acquisition Specialist at [Company Name]. I came across your profile and was genuinely impressed by your expertise in cybersecurity, particularly your work at Allsafe Security and your specialized skills in penetration testing and ethical hacking. Your contributions to open-source projects and active engagement in cybersecurity forums also caught my attention—it's clear your passion extends well beyond your day-to-day responsibilities.
#
# We're currently seeking exceptional cybersecurity talent for **senior-level positions focused on advanced threat detection and network security** at [Company Name], where we're **building cutting-edge security solutions for enterprise clients and fostering a culture of innovation and continuous learning**. Given your technical expertise and proven track record in identifying and addressing complex vulnerabilities, I believe there could be a strong mutual fit worth exploring.
#
# Would you be open to a brief, confidential conversation in the coming week? I'm flexible with timing and happy to work around your schedule.
#
# Thank you for considering this opportunity, Elliot. I look forward to the possibility of connecting with you.
#
# Warm regards,
#
# [Your Name]
# Talent Acquisition Specialist
# [Company Name]
# [Email Address]
# [Phone Number]

# %% [markdown]
# ## Summary
#
# You've now seen five workflow patterns for coordinating multiple LLM calls:
#
# 1. **Prompt Chaining**: Sequential steps building on each other
# 2. **Parallelization**: Independent tasks running concurrently
# 3. **Routing**: Dynamic path selection based on input type
# 4. **Orchestrator-Workers**: Central coordinator delegating to specialized workers
# 5. **Evaluator-Optimizer**: Iterative refinement through feedback loops
#
# **Key takeaway:** Complex AI applications rarely use a single LLM call. These patterns help you structure multi-LLM workflows for reliability, efficiency, and quality.
#
# **Coming up next:** We'll demo the Model Context Protocol (MCP), a standard for building reusable tool servers. Instead of reimplementing GitHub APIs, search functions, or other tools for each application, MCP lets you define them once and make them discoverable to any LLM that supports the protocol.
